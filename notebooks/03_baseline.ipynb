# %% [markdown]
# # 03 - Modelo Baseline
# ---
# ImplementaciÃ³n de un modelo baseline simple como referencia inicial. Establece el mÃ­nimo rendimiento esperado.
#
# **Este notebook estÃ¡ preparado para ejecutarse directamente en Google Colab.**
#
# > Autor: JosÃ© Alfredo MartÃ­nez ValdÃ©s

# %%
# === CONFIGURACIÃ“N INICIAL ===
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
print('Entorno cargado correctamente.')
