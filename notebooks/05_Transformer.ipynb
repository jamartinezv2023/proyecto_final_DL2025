# %% [markdown]
# # 05 - Modelo Transformer
# ---
# ImplementaciÃ³n del Transformer para secuencias, codificaciÃ³n posicional, entrenamiento y evaluaciÃ³n comparativa.
#
# **Este notebook estÃ¡ preparado para ejecutarse directamente en Google Colab.**
#
# > Autor: JosÃ© Alfredo MartÃ­nez ValdÃ©s

# %%
# === CONFIGURACIÃ“N INICIAL ===
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
print('Entorno cargado correctamente.')
