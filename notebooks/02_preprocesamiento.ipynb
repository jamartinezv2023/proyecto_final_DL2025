# %% [markdown]
# # 02 - Preprocesamiento
# ---
# Limpieza de datos, generaciÃ³n de etiquetas, normalizaciÃ³n, diferencia de goles, ventanas temporales y divisiÃ³n temporal train/val/test.
#
# **Este notebook estÃ¡ preparado para ejecutarse directamente en Google Colab.**
#
# > Autor: JosÃ© Alfredo MartÃ­nez ValdÃ©s

# %%
# === CONFIGURACIÃ“N INICIAL ===
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
print('Entorno cargado correctamente.')
