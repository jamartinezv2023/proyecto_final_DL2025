# %% [markdown]
# # 06 - Iteraciones Experimentales
# ---
# Pruebas adicionales, tuning de hiperparÃ¡metros, comparaciÃ³n final de modelos y conclusiones.
#
# **Este notebook estÃ¡ preparado para ejecutarse directamente en Google Colab.**
#
# > Autor: JosÃ© Alfredo MartÃ­nez ValdÃ©s

# %%
# === CONFIGURACIÃ“N INICIAL ===
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
print('Entorno cargado correctamente.')
