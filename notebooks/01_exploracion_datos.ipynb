# %% [markdown]
# # 01 - ExploraciÃ³n de Datos
# ---
# ExploraciÃ³n inicial del dataset, revisiÃ³n de estructura, valores faltantes, tendencias y distribuciÃ³n de clases.
#
# **Este notebook estÃ¡ preparado para ejecutarse directamente en Google Colab.**
#
# > Autor: JosÃ© Alfredo MartÃ­nez ValdÃ©s

# %%
# === CONFIGURACIÃ“N INICIAL ===
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
print('Entorno cargado correctamente.')
